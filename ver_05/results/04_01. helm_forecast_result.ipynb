# %% [markdown]
# # H-ELM forecast

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib notebook

import seaborn as sns
import os.path

# %%
forecast_result_file_path = '/Users/JH/Documents/GitHub/PowerForecast/ver_05/forecasting_models/HELM/forecast_result'
area = 'ACTEWAGL'
layer = 'layer1'
file_path = os.path.join(forecast_result_file_path, area)
file_path = os.path.join(file_path, layer)

result_file_00 = os.path.join(file_path, 'helm_forecast_result_wd.csv')
result_file_01 = os.path.join(file_path, 'helm_forecast_result_lwd.csv')
result_file_02 = os.path.join(file_path, 'helm_forecast_result_lww.csv')
result_file_03 = os.path.join(file_path, 'helm_forecast_result_lwdw.csv')



f_00 = pd.read_csv(result_file_00)
f_01 = pd.read_csv(result_file_01)
f_02 = pd.read_csv(result_file_02)
f_03 = pd.read_csv(result_file_03)



result_00 = f_00['RMSE'].tolist()
result_01 = f_01['RMSE'].tolist()
result_02 = f_02['RMSE'].tolist()
result_03 = f_03['RMSE'].tolist()

# %% [markdown]
# # Total Result

# %%
plot_00 = sns.distplot(result_00, norm_hist=True, kde_kws={"label":"case 00"}, color='blue')
plot_01 = sns.distplot(result_01, norm_hist=True, kde_kws={"label":"case 01"}, color='green')
plot_02 = sns.distplot(result_02, norm_hist=True, kde_kws={"label":"case 02"}, color='red')
plot_03 = sns.distplot(result_03, norm_hist=True, kde_kws={"label":"case 02"}, color='purple')

plt.title('H-ELM', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_00 = np.mean(result_00)
std_00 = np.std(result_00)
mean_01 = np.mean(result_01)
std_01 = np.std(result_01)
mean_02 = np.mean(result_02)
std_02 = np.std(result_02)
mean_03 = np.mean(result_03)
std_03 = np.std(result_03)

print 'Case 00 [RMSE/std] = ',
print str(mean_00) + ' / ' + str(std_00)
print 'Case 01 [RMSE/std] = ',
print str(mean_01) + ' / ' + str(std_01)
print 'Case 02 [RMSE/std] = ',
print str(mean_02) + ' / ' + str(std_02)
print 'Case 03 [RMSE/std] = ',
print str(mean_03) + ' / ' + str(std_03)
# Out:
# Case 00 [RMSE/std] =  0.16060354 / 0.000197381530038
# Case 01 [RMSE/std] =  0.084789353 / 0.000724360918597
# Case 02 [RMSE/std] =  0.091978838 / 0.000735274775683
# Case 03 [RMSE/std] =  0.08011011 / 0.000665245296037

# %% [markdown]
# # Case 00

# %%
plot_00 = sns.distplot(result_00, norm_hist=True, kde=True, rug=True, color='blue')
plt.title('H-ELM - case 00', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
print 'number of test samples = ',
print str(len(result_00))
print

print 'mean value of RMSE = ',
print str(mean_00)
print 'std value of RMSE = ',
print str(std_00)
print

print 'min RMSE = ',
print str(min(result_00))
print 'max RMSE = ',
print str(max(result_00))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.16060354
# std value of RMSE =  0.000197381530038
#
# min RMSE =  0.16001
# max RMSE =  0.16154

# %% [markdown]
# # Case 01

# %%
plot_01 = sns.distplot(result_01, norm_hist=True, kde=True, rug=True, color='green')
plt.title('H-ELM - case 01', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
print 'number of test samples = ',
print str(len(result_01))
print

print 'mean value of RMSE = ',
print str(mean_01)
print 'std value of RMSE = ',
print str(std_01)
print

print 'min RMSE = ',
print str(min(result_01))
print 'max RMSE = ',
print str(max(result_01))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.084789353
# std value of RMSE =  0.000724360918597
#
# min RMSE =  0.082883
# max RMSE =  0.087292

# %% [markdown]
# # Case 02

# %%
plot_02 = sns.distplot(result_02, norm_hist=True, kde=True, rug=True, color='red')
plt.title('H-ELM - case 02', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
print 'number of test samples = ',
print str(len(result_02))
print

print 'mean value of RMSE = ',
print str(mean_02)
print 'std value of RMSE = ',
print str(std_02)
print

print 'min RMSE = ',
print str(min(result_02))
print 'max RMSE = ',
print str(max(result_02))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.091978838
# std value of RMSE =  0.000735274775683
#
# min RMSE =  0.089585
# max RMSE =  0.094167

# %% [markdown]
# # Case 03

# %%
plot_03 = sns.distplot(result_03, norm_hist=True, kde=True, rug=True, color='purple')
plt.title('H-ELM - case 03', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
print 'number of test samples = ',
print str(len(result_03))
print

print 'mean value of RMSE = ',
print str(mean_03)
print 'std value of RMSE = ',
print str(std_03)
print

print 'min RMSE = ',
print str(min(result_03))
print 'max RMSE = ',
print str(max(result_03))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.08011011
# std value of RMSE =  0.000665245296037
#
# min RMSE =  0.077829
# max RMSE =  0.083291
