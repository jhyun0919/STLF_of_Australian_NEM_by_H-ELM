# %% [markdown]
# # H-ELM forecast

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib notebook

import seaborn as sns
import os.path

# %%
forecast_result_file_path = '/Users/JH/Documents/GitHub/PowerForecast/ver_05/forecasting_models/HELM/forecast_result'
area = 'ACTEWAGL'
layer = 'layer1'
file_path = os.path.join(forecast_result_file_path, area)
file_path = os.path.join(file_path, layer)

result_file_00 = os.path.join(file_path, 'helm_forecast_result_wd.csv')
result_file_01 = os.path.join(file_path, 'helm_forecast_result_lwd.csv')
result_file_02 = os.path.join(file_path, 'helm_forecast_result_lww.csv')
result_file_03 = os.path.join(file_path, 'helm_forecast_result_lwdw.csv')



f_00 = pd.read_csv(result_file_00)
f_01 = pd.read_csv(result_file_01)
f_02 = pd.read_csv(result_file_02)
f_03 = pd.read_csv(result_file_03)



Training_RMSE_00 = f_00['Training'].tolist()
Testing_RMSE_00 = f_00['Testing'].tolist()
Training_RMSE_01 = f_01['Training'].tolist()
Testing_RMSE_01 = f_01['Testing'].tolist()
Training_RMSE_02 = f_02['Training'].tolist()
Testing_RMSE_02 = f_02['Testing'].tolist()
Training_RMSE_03 = f_03['Training'].tolist()
Testing_RMSE_03 = f_03['Testing'].tolist()

# %% [markdown]
# # Total Result

# %% [markdown]
# ### Training RMSE summary

# %%
plot_train_00 = sns.distplot(Training_RMSE_00, norm_hist=True, kde_kws={"label":"case 00:train"}, color='#658cbb')
plot_train_01 = sns.distplot(Training_RMSE_01, norm_hist=True, kde_kws={"label":"case 01:train"}, color='#7bb274')
plot_train_02 = sns.distplot(Training_RMSE_02, norm_hist=True, kde_kws={"label":"case 02:train"}, color='#d3494e')
plot_train_03 = sns.distplot(Training_RMSE_03, norm_hist=True, kde_kws={"label":"case 03:train"}, color='#916e99')

plt.title('H-ELM', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)

ax = plt.xlim(0.06, 0.17)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
train_mean_00 = np.mean(Training_RMSE_00)
train_std_00 = np.std(Training_RMSE_00)
train_mean_01 = np.mean(Training_RMSE_01)
train_std_01 = np.std(Training_RMSE_01)
train_mean_02 = np.mean(Training_RMSE_02)
train_std_02 = np.std(Training_RMSE_02)
train_mean_03 = np.mean(Training_RMSE_03)
train_std_03 = np.std(Training_RMSE_03)

print 'Case 00 [RMSE/std] = ',
print str(train_mean_00) + ' / ' + str(train_std_00)
print 'Case 01 [RMSE/std] = ',
print str(train_mean_01) + ' / ' + str(train_std_01)
print 'Case 02 [RMSE/std] = ',
print str(train_mean_02) + ' / ' + str(train_std_02)
print 'Case 03 [RMSE/std] = ',
print str(train_mean_03) + ' / ' + str(train_std_03)
# Out:
# Case 00 [RMSE/std] =  0.14306136 / 0.000156562927924
# Case 01 [RMSE/std] =  0.061866805 / 0.000146107545921
# Case 02 [RMSE/std] =  0.072700017 / 0.000158758957892
# Case 03 [RMSE/std] =  0.063687239 / 0.000192428983989

# %% [markdown]
# ### Testing RMSE summary

# %%
plot_test_00 = sns.distplot(Testing_RMSE_00, norm_hist=True, kde_kws={"label":"case 00:test"}, color='blue')
plot_test_01 = sns.distplot(Testing_RMSE_01, norm_hist=True, kde_kws={"label":"case 01:test"}, color='green')
plot_test_02 = sns.distplot(Testing_RMSE_02, norm_hist=True, kde_kws={"label":"case 02:test"}, color='red')
plot_test_03 = sns.distplot(Testing_RMSE_03, norm_hist=True, kde_kws={"label":"case 03:test"}, color='purple')

plt.title('H-ELM', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)

ax = plt.xlim(0.06, 0.17)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
test_mean_00 = np.mean(Testing_RMSE_00)
test_std_00 = np.std(Testing_RMSE_00)
test_mean_01 = np.mean(Testing_RMSE_01)
test_std_01 = np.std(Testing_RMSE_01)
test_mean_02 = np.mean(Testing_RMSE_02)
test_std_02 = np.std(Testing_RMSE_02)
test_mean_03 = np.mean(Testing_RMSE_03)
test_std_03 = np.std(Testing_RMSE_03)

print 'Case 00 [RMSE/std] = ',
print str(test_mean_00) + ' / ' + str(test_std_00)
print 'Case 01 [RMSE/std] = ',
print str(test_mean_01) + ' / ' + str(test_std_01)
print 'Case 02 [RMSE/std] = ',
print str(test_mean_02) + ' / ' + str(test_std_02)
print 'Case 03 [RMSE/std] = ',
print str(test_mean_03) + ' / ' + str(test_std_03)
# Out:
# Case 00 [RMSE/std] =  0.16046469 / 0.000211855384402
# Case 01 [RMSE/std] =  0.084134204 / 0.000738290998444
# Case 02 [RMSE/std] =  0.091034215 / 0.00073028287586
# Case 03 [RMSE/std] =  0.080043132 / 0.000597998594125

# %% [markdown]
# # Case 00

# %%
plot_train_00 = sns.distplot(Training_RMSE_00, norm_hist=True, kde_kws={"label":"case 00:train"}, color='#658cbb')
plot_test_00 = sns.distplot(Testing_RMSE_00, norm_hist=True, kde_kws={"label":"case 00:test"}, color='blue')

plt.title('H-ELM - case 00', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)

ax = plt.xlim(0.1, 0.17)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
print 'number of test samples = ',
print str(len(Training_RMSE_00))
print

print 'mean value of training RMSE = ',
print str(train_mean_00)
print 'std value of training RMSE = ',
print str(train_std_00)
print

print 'min training RMSE = ',
print str(min(Training_RMSE_00))
print 'max training RMSE = ',
print str(max(Training_RMSE_00))
# Out:
# number of test samples =  1000
#
# mean value of training RMSE =  0.14306136
# std value of training RMSE =  0.000156562927924
#
# min training RMSE =  0.14261
# max training RMSE =  0.14372

# %%
print 'number of test samples = ',
print str(len(Testing_RMSE_00))
print

print 'mean value of testing RMSE = ',
print str(test_mean_00)
print 'std value of testing RMSE = ',
print str(test_std_00)
print

print 'min testing RMSE = ',
print str(min(Testing_RMSE_00))
print 'max testing RMSE = ',
print str(max(Testing_RMSE_00))
# Out:
# number of test samples =  1000
#
# mean value of testing RMSE =  0.16046469
# std value of testing RMSE =  0.000211855384402
#
# min testing RMSE =  0.15997
# max testing RMSE =  0.16137

# %% [markdown]
# # Case 01

# %%
plot_train_01 = sns.distplot(Training_RMSE_01, norm_hist=True, kde_kws={"label":"case 01:train"}, color='#7bb274')
plot_test_01 = sns.distplot(Testing_RMSE_01, norm_hist=True, kde_kws={"label":"case 01:test"}, color='green')

plt.title('H-ELM - case 01', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)

ax = plt.xlim(0.06, 0.095)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
print 'number of test samples = ',
print str(len(Training_RMSE_01))
print

print 'mean value of training RMSE = ',
print str(train_mean_01)
print 'std value of training RMSE = ',
print str(train_std_01)
print

print 'min training RMSE = ',
print str(min(Training_RMSE_01))
print 'max training RMSE = ',
print str(max(Training_RMSE_01))
# Out:
# number of test samples =  1000
#
# mean value of training RMSE =  0.061866805
# std value of training RMSE =  0.000146107545921
#
# min training RMSE =  0.06134
# max training RMSE =  0.06238

# %%
print 'number of test samples = ',
print str(len(Testing_RMSE_01))
print

print 'mean value of testing RMSE = ',
print str(test_mean_01)
print 'std value of testing RMSE = ',
print str(test_std_01)
print

print 'min testing RMSE = ',
print str(min(Testing_RMSE_01))
print 'max testing RMSE = ',
print str(max(Testing_RMSE_01))
# Out:
# number of test samples =  1000
#
# mean value of testing RMSE =  0.084134204
# std value of testing RMSE =  0.000738290998444
#
# min testing RMSE =  0.082326
# max testing RMSE =  0.086298

# %% [markdown]
# # Case 02

# %%
plot_train_02 = sns.distplot(Training_RMSE_02, norm_hist=True, kde_kws={"label":"case 02:train"}, color='#d3494e')
plot_test_02 = sns.distplot(Testing_RMSE_02, norm_hist=True, kde_kws={"label":"case 02:test"}, color='red')

plt.title('H-ELM - case 02', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)

ax = plt.xlim(0.06, 0.1)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
print 'number of test samples = ',
print str(len(Training_RMSE_02))
print

print 'mean value of training RMSE = ',
print str(train_mean_02)
print 'std value of training RMSE = ',
print str(train_std_02)
print

print 'min training RMSE = ',
print str(min(Training_RMSE_02))
print 'max training RMSE = ',
print str(max(Training_RMSE_02))
# Out:
# number of test samples =  1000
#
# mean value of training RMSE =  0.072700017
# std value of training RMSE =  0.000158758957892
#
# min training RMSE =  0.072205
# max training RMSE =  0.073254

# %%
print 'number of test samples = ',
print str(len(Testing_RMSE_02))
print

print 'mean value of testing RMSE = ',
print str(test_mean_02)
print 'std value of testing RMSE = ',
print str(test_std_02)
print

print 'min testing RMSE = ',
print str(min(Testing_RMSE_02))
print 'max testing RMSE = ',
print str(max(Testing_RMSE_02))
# Out:
# number of test samples =  1000
#
# mean value of testing RMSE =  0.091034215
# std value of testing RMSE =  0.00073028287586
#
# min testing RMSE =  0.088843
# max testing RMSE =  0.093722

# %% [markdown]
# # Case 03

# %%
plot_train_03 = sns.distplot(Training_RMSE_03, norm_hist=True, kde_kws={"label":"case 03:train"}, color='#916e99')
plot_test_03 = sns.distplot(Testing_RMSE_03, norm_hist=True, kde_kws={"label":"case 03:test"}, color='purple')

plt.title('H-ELM - case 03', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)

ax = plt.xlim(0.06, 0.09)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
print 'number of test samples = ',
print str(len(Training_RMSE_03))
print

print 'mean value of training RMSE = ',
print str(train_mean_03)
print 'std value of training RMSE = ',
print str(train_std_00)
print

print 'min training RMSE = ',
print str(min(Training_RMSE_03))
print 'max training RMSE = ',
print str(max(Training_RMSE_03))
# Out:
# number of test samples =  1000
#
# mean value of training RMSE =  0.063687239
# std value of training RMSE =  0.000156562927924
#
# min training RMSE =  0.063015
# max training RMSE =  0.064389

# %%
print 'number of test samples = ',
print str(len(Testing_RMSE_03))
print

print 'mean value of testing RMSE = ',
print str(test_mean_03)
print 'std value of testing RMSE = ',
print str(test_std_03)
print

print 'min testing RMSE = ',
print str(min(Testing_RMSE_03))
print 'max testing RMSE = ',
print str(max(Testing_RMSE_03))
# Out:
# number of test samples =  1000
#
# mean value of testing RMSE =  0.080043132
# std value of testing RMSE =  0.000597998594125
#
# min testing RMSE =  0.078343
# max testing RMSE =  0.082108
