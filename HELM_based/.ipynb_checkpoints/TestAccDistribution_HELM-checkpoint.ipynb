# %% [markdown]
# # HELM

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib notebook

import seaborn as sns

# %%
result_file_pre = './H-ELM/helm_preprocessed_result.csv'
result_file_raw = './H-ELM/helm_raw_result.csv'

f_pre = pd.read_csv(result_file_pre)
f_raw = pd.read_csv(result_file_raw)

result_pre = f_pre['RMSE'].tolist()
result_raw = f_raw['RMSE'].tolist()

# %% [markdown]
# # Preprocessed

# %%
plot_pre = sns.distplot(result_pre, norm_hist=True, kde=True, rug=True)
plt.title('HELM - preprocessed', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_pre = np.mean(result_pre)
std_pre = np.std(result_pre)

print 'number of test samples = ',
print str(len(result_pre))
print

print 'mean value of TestAcc with preprocessed data = ',
print str(mean_pre)
print 'std value of TestAcc with preprocessed data = ',
print str(std_pre)
print

print 'min Test RMSE = ',
print str(min(result_pre))
print 'max Test RMSE = ',
print str(max(result_pre))
# Out:
# number of test samples =  1000
#
# mean value of TestAcc with preprocessed data =  0.061838965
# std value of TestAcc with preprocessed data =  0.00282407457971
#
# min Test RMSE =  0.053118
# max Test RMSE =  0.073082

# %% [markdown]
# # Raw

# %%
plot_raw = sns.distplot(result_raw, norm_hist=True, kde=True, rug=True, color='g')
plt.title('HELM - raw', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_raw = np.mean(result_raw)
std_raw = np.std(result_raw)

print 'number of test samples = ',
print str(len(result_raw))
print

print 'mean value of TestAcc with raw data = ',
print str(mean_raw)
print 'std value of TestAcc with raw data = ',
print str(std_raw)
print

print 'min Test RMSE = ',
print str(min(result_raw))
print 'max Test RMSE = ',
print str(max(result_raw))
# Out:
# number of test samples =  1000
#
# mean value of TestAcc with raw data =  0.22272991
# std value of TestAcc with raw data =  0.0834939381997
#
# min Test RMSE =  0.10162
# max Test RMSE =  0.75942

# %% [markdown]
# # Total Result

# %%
plot_pre = sns.distplot(result_pre, norm_hist=True, kde_kws={"label":"preprocessed"})
plot_raw = sns.distplot(result_raw, norm_hist=True, kde_kws={"label":"raw"})
plt.title('HELM', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)

ax = plt.xlim(0, 0.5)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()
