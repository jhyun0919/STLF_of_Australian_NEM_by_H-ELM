# %% [markdown]
# # H-ELM optimal

# %%
import numpy as np
import pandas as pd
import operator

import matplotlib.pyplot as plt
# %matplotlib notebook

#import seaborn as sns
import os.path
import sys
sys.path.insert(0, '/Users/JH/Documents/GitHub/PowerForecast/ver_06/util')
import app as ap

# %%
optimal_file_path = '/Users/JH/Documents/GitHub/PowerForecast/ver_06/forecasting_models/HELM/optimal_data'
area = 'ACTEWAGL'
layer = 'layer1'
file_path = os.path.join(optimal_file_path, area)
file_path = os.path.join(file_path, layer)

result_file_00 = os.path.join(file_path, 'helm_optimal_wd.csv')
result_file_01 = os.path.join(file_path, 'helm_optimal_lwd.csv')
result_file_02 = os.path.join(file_path, 'helm_optimal_lww.csv')
result_file_03 = os.path.join(file_path, 'helm_optimal_lwdw1.csv')

f_00 = pd.read_csv(result_file_00)
f_01 = pd.read_csv(result_file_01)
f_02 = pd.read_csv(result_file_02)
f_03 = pd.read_csv(result_file_03)

# %%
RMSE_00 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.rmse_data2df(np.array(f_00['RMSE'].tolist())))
RMSE_01 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.rmse_data2df(np.array(f_01['RMSE'].tolist())))
RMSE_02 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.rmse_data2df(np.array(f_02['RMSE'].tolist())))
RMSE_03 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.rmse_data2df(np.array(f_03['RMSE'].tolist())))

# %%
MAPE_00 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.mape_data2df(np.array(f_00['MAPE'].tolist())))
MAPE_01 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.mape_data2df(np.array(f_01['MAPE'].tolist())))
MAPE_02 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.mape_data2df(np.array(f_02['MAPE'].tolist())))
MAPE_03 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.mape_data2df(np.array(f_03['MAPE'].tolist())))

# %%
MAE_00 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.mae_data2df(np.array(f_00['MAE'].tolist())))
MAE_01 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.mae_data2df(np.array(f_01['MAE'].tolist())))
MAE_02 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.mae_data2df(np.array(f_02['MAE'].tolist())))
MAE_03 = ap.Numpy2Pandas.add_number_index(ap.Numpy2Pandas.mae_data2df(np.array(f_03['MAE'].tolist())))

# %% [markdown]
# ---

# %%
def total_result(acc_type, df_00, df_01, df_02, df_03):
    idx_00 = df_00[acc_type].idxmin()-1
    idx_01 = df_01[acc_type].idxmin()-1
    idx_02 = df_02[acc_type].idxmin()-1
    idx_03 = df_03[acc_type].idxmin()-1
    
    min_00 = df_00[acc_type].iloc[idx_00]
    min_01 = df_01[acc_type].iloc[idx_01]
    min_02 = df_02[acc_type].iloc[idx_02]
    min_03 = df_03[acc_type].iloc[idx_03]
    
    print 'case_00 : idx = ' + str(idx_00) + ' / value = ' + str(min_00)
    print 'case_01 : idx = ' + str(idx_01) + ' / value = ' + str(min_01)
    print 'case_02 : idx = ' + str(idx_02) + ' / value = ' + str(min_02)
    print 'case_03 : idx = ' + str(idx_03) + ' / value = ' + str(min_03)

# %%
def total_RMSE_graph(df_00, df_01, df_02, df_03):
    font_size = 6

    plt.subplot(221)
    plt.plot(df_00[:], color='blue', label='HELM:Case00')
    plt.tick_params(labelsize=font_size)
    plt.legend(loc=1)

    plt.subplot(222)
    plt.plot(df_01[30:], color='green', label='HELM:Case01')
    plt.tick_params(labelsize=font_size)
    plt.legend(loc=1)
    plt.ylim(0.077, 0.1)

    plt.subplot(223)
    plt.plot(df_02[30:], color='red', label='HELM:Case02')
    plt.tick_params(labelsize=font_size)
    plt.legend(loc=1)
    plt.ylim(0.077, 0.1)

    plt.subplot(224)
    plt.plot(df_03[30:], color='purple', label='HELM:Case03')
    plt.tick_params(labelsize=font_size)
    plt.legend(loc=1)
    plt.ylim(0.077, 0.1)

# %%
def total_MAPE_graph(df_00, df_01, df_02, df_03):
    font_size = 6

    plt.subplot(221)
    plt.plot(df_00[:], color='blue', label='HELM:Case00')
    plt.tick_params(labelsize=font_size)
    plt.legend(loc=1)

    plt.subplot(222)
    plt.plot(df_01[30:], color='green', label='HELM:Case01')
    plt.tick_params(labelsize=font_size)
    plt.ylim(11, 15)
    plt.legend(loc=1)

    plt.subplot(223)
    plt.plot(df_02[30:], color='red', label='HELM:Case02')
    plt.tick_params(labelsize=font_size)
    plt.ylim(11, 15)
    plt.legend(loc=1)


    plt.subplot(224)
    plt.plot(df_03[30:], color='purple', label='HELM:Case03')
    plt.tick_params(labelsize=font_size)
    plt.ylim(11, 15)
    plt.legend(loc=1)

# %%
def total_MAE_graph(df_00, df_01, df_02, df_03):
    font_size = 6

    plt.subplot(221)
    plt.plot(df_00[:], color='blue', label='HELM:Case00')
    plt.tick_params(labelsize=font_size)
    plt.legend(loc=1)

    plt.subplot(222)
    plt.plot(df_01[30:], color='green', label='HELM:Case01')
    plt.tick_params(labelsize=font_size)
    plt.legend(loc=1)
    plt.ylim(10000, 13000)

    plt.subplot(223)
    plt.plot(df_02[30:], color='red', label='HELM:Case02')
    plt.tick_params(labelsize=font_size)
    plt.legend(loc=1)
    plt.ylim(10000, 13000)

    plt.subplot(224)
    plt.plot(df_03[30:], color='purple', label='HELM:Case03')
    plt.tick_params(labelsize=font_size)
    plt.legend(loc=1)
    plt.ylim(10000, 13000)

# %% [markdown]
# ---

# %% [markdown]
# ### RMSE result

# %%
total_result('RMSE', RMSE_00, RMSE_01, RMSE_02, RMSE_03)
# Out:
# case_00 : idx = 16 / value = 0.16042
# case_01 : idx = 208 / value = 0.083763
# case_02 : idx = 203 / value = 0.090688
# case_03 : idx = 155 / value = 0.079731

# %%
total_RMSE_graph(RMSE_00, RMSE_01, RMSE_02, RMSE_03)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()

# %% [markdown]
# ---

# %% [markdown]
# ### MAPE result

# %%
total_result('MAPE', MAPE_00, MAPE_01, MAPE_02, MAPE_03)
# Out:
# case_00 : idx = 258 / value = 26.868
# case_01 : idx = 208 / value = 11.597
# case_02 : idx = 196 / value = 12.695
# case_03 : idx = 168 / value = 11.282

# %%
total_MAPE_graph(MAPE_00, MAPE_01, MAPE_02, MAPE_03)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()

# %% [markdown]
# ---

# %% [markdown]
# ### MAE result

# %%
total_result('MAE', MAE_00, MAE_01, MAE_02, MAE_03)
# Out:
# case_00 : idx = 171 / value = 21616
# case_01 : idx = 208 / value = 10788
# case_02 : idx = 196 / value = 11694
# case_03 : idx = 155 / value = 10332

# %%
total_MAE_graph(MAE_00, MAE_01, MAE_02, MAE_03)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()
