# %% [markdown]
# # ELM optimal

# %%
import numpy as np
import pandas as pd
import operator

import matplotlib.pyplot as plt
# %matplotlib notebook

import seaborn as sns
import os.path

# %%
file_path = '/Users/JH/Documents/GitHub/PowerForecast/ver_04/forecasting_models/ELM/optimal_data'

result_file_00 = os.path.join(file_path, 'elm_optimal.csv')
#result_file_01 = os.path.join(file_path, 'elm_optimal_w.csv')
#result_file_02 = os.path.join(file_path, 'elm_optimal_dw.csv')


f_00 = pd.read_csv(result_file_00)
#f_01 = pd.read_csv(result_file_01)
#f_02 = pd.read_csv(result_file_02)


RMSE_00 = f_00['RMSE'].tolist()
#MAPE_00 = f_00['MAPE'].tolist()
#RMSE_01 = f_01['RMSE'].tolist()
#MAPE_01 = f_01['MAPE'].tolist()
#RMSE_02 = f_02['RMSE'].tolist()
#MAPE_02 = f_02['MAPE'].tolist()

# %%
plot_RMSE_00 = plt.plot(RMSE_00, color='blue')
#plot_RMSE_01 = plt.plot(RMSE_01, color='green')
#plot_RMSE_02 = plt.plot(RMSE_02, color='red')
plt.title('ELM', fontsize=13)
plt.xlabel('Hidden node number', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %% [markdown]
# ---------

# %% [markdown]
# # Case 00 optimal range

# %%
plot_RMSE_00 = plt.plot(RMSE_00[:100], color='blue')
plt.title('ELM', fontsize=13)
plt.xlabel('Hidden node number', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
print RMSE_00.index(min(RMSE_00))
print min(RMSE_00)
# Out:
# 9
# 0.54901

# %% [markdown]
# optinal range [20, 30]

# %% [markdown]
# ---------

# %% [markdown]
# # Case 01 optimal range

# %%
plot_RMSE_01 = plt.plot(RMSE_01[:], color='green')
plt.title('ELM', fontsize=13)
plt.xlabel('Hidden node number', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
print RMSE_01.index(min(RMSE_01))
print min(RMSE_01)
# Out:
# 144
# 0.27804

# %% [markdown]
# optinal range [40, 60]

# %% [markdown]
# ---------

# %% [markdown]
# # Case 02 optimal range

# %%
plot_RMSE_02 = plt.plot(RMSE_02[:], color='red')
plt.title('ELM', fontsize=13)
plt.xlabel('Hidden node number', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
print RMSE_02.index(min(RMSE_02))
print min(RMSE_02)
# Out:
# 113
# 0.278

# %% [markdown]
# optinal range [20, 40]

# %% [markdown]
# ---------
