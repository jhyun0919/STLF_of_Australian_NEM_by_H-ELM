# %% [markdown]
# # ELM forcast

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib notebook

import seaborn as sns
import os.path

# %%
file_path = '/Users/JH/Documents/GitHub/PowerForecast/ver_04/forecasting_models/ELM/forecast_result'

result_file_00 = os.path.join(file_path, 'elm_forecast_result.csv')
#result_file_01 = os.path.join(file_path, 'elm_forecast_result01.csv')
#result_file_02 = os.path.join(file_path, 'elm_forecast_result02.csv')


f_00 = pd.read_csv(result_file_00)
#f_01 = pd.read_csv(result_file_01)
#f_02 = pd.read_csv(result_file_02)


RMSE_00 = f_00['RMSE'].tolist()
#MAPE_00 = f_00['MAPE'].tolist()
#RMSE_01 = f_01['RMSE'].tolist()
#MAPE_01 = f_01['MAPE'].tolist()
#RMSE_02 = f_02['RMSE'].tolist()
#MAPE_02 = f_02['MAPE'].tolist()

# %% [markdown]
# # Total Result

# %%
plot_RMSE_00 = sns.distplot(RMSE_00, norm_hist=True, kde_kws={"label":"case 00"}, color='blue')
#plot_RMSE_01 = sns.distplot(RMSE_01, norm_hist=True, kde_kws={"label":"case 01"}, color='green')
#plot_RMSE_02 = sns.distplot(RMSE_02, norm_hist=True, kde_kws={"label":"case 02"}, color='red')

plt.title('ELM', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %% [markdown]
# # Case 00

# %%
plot_RMSE_00 = sns.distplot(RMSE_00, norm_hist=True, kde=True, rug=True, color='blue')
plt.title('ELM - case 00', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_00 = np.mean(RMSE_00)
std_00 = np.std(RMSE_00)

print 'number of test samples = ',
print str(len(RMSE_00))
print

print 'mean value of RMSE = ',
print str(mean_00)
print 'std value of RMSE = ',
print str(std_00)
print

print 'min RMSE = ',
print str(min(RMSE_00))
print 'max RMSE = ',
print str(max(RMSE_00))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.55392543
# std value of RMSE =  0.00415730023153
#
# min RMSE =  0.54063
# max RMSE =  0.57155

# %% [markdown]
# # Case 01

# %%
plot_RMSE_01 = sns.distplot(RMSE_01, norm_hist=True, kde=True, rug=True, color='green')
plt.title('ELM - case 01', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_01 = np.mean(RMSE_01)
std_01 = np.std(RMSE_01)

print 'number of test samples = ',
print str(len(RMSE_01))
print

print 'mean value of RMSE = ',
print str(mean_01)
print 'std value of RMSE = ',
print str(std_01)
print

print 'min RMSE = ',
print str(min(RMSE_01))
print 'max RMSE = ',
print str(max(RMSE_01))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.2787011
# std value of RMSE =  0.00110274847087
#
# min RMSE =  0.27564
# max RMSE =  0.28223

# %% [markdown]
# # Case 02

# %%
plot_RMSE_02 = sns.distplot(RMSE_02, norm_hist=True, kde=True, rug=True, color='red')
plt.title('ELM - case 02', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_02 = np.mean(RMSE_02)
std_02 = np.std(RMSE_02)

print 'number of test samples = ',
print str(len(RMSE_02))
print

print 'mean value of RMSE = ',
print str(mean_02)
print 'std value of RMSE = ',
print str(std_02)
print

print 'min RMSE = ',
print str(min(RMSE_02))
print 'max RMSE = ',
print str(max(RMSE_02))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.27871634
# std value of RMSE =  0.00132754397456
#
# min RMSE =  0.27454
# max RMSE =  0.28312
