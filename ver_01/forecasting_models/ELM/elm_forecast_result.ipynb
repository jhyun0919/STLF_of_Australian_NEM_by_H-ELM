# %% [markdown]
# # ELM forcast

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib notebook

import seaborn as sns

# %%
result_file_00 = './elm_forecast_result00.csv'
result_file_01 = './elm_forecast_result01.csv'
result_file_02 = './elm_forecast_result02.csv'
result_file_03 = './elm_forecast_result03.csv'
result_file_04 = './elm_forecast_result04.csv'

f_00 = pd.read_csv(result_file_00)
f_01 = pd.read_csv(result_file_01)
f_02 = pd.read_csv(result_file_02)
f_03 = pd.read_csv(result_file_03)
f_04 = pd.read_csv(result_file_04)

result_00 = f_00['MAPE'].tolist()
result_01 = f_01['MAPE'].tolist()
result_02 = f_02['MAPE'].tolist()
result_03 = f_03['MAPE'].tolist()
result_04 = f_04['MAPE'].tolist()

# %% [markdown]
# # Total Result

# %%
plot_00 = sns.distplot(result_00, norm_hist=True, kde_kws={"label":"case 00"}, color='blue')
plot_01 = sns.distplot(result_01, norm_hist=True, kde_kws={"label":"case 01"}, color='green')
plot_02 = sns.distplot(result_02, norm_hist=True, kde_kws={"label":"case 02"}, color='red')
plot_03 = sns.distplot(result_03, norm_hist=True, kde_kws={"label":"case 03"}, color='purple')
plot_04 = sns.distplot(result_04, norm_hist=True, kde_kws={"label":"case 04"}, color='orange')
plt.title('ELM', fontsize=13)
plt.xlabel(' RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)

ax = plt.xlim(0, 2)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %% [markdown]
# # Case 00

# %%
plot_00 = sns.distplot(result_00, norm_hist=True, kde=True, rug=True, color='blue')
plt.title('ELM - case 00', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_00 = np.mean(result_00)
std_00 = np.std(result_00)

print 'number of test samples = ',
print str(len(result_00))
print

print 'mean value of RMSE = ',
print str(mean_00)
print 'std value of RMSE = ',
print str(std_00)
print

print 'min RMSE = ',
print str(min(result_00))
print 'max RMSE = ',
print str(max(result_00))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.67355663
# std value of RMSE =  0.136919215951
#
# min RMSE =  0.51313
# max RMSE =  1.7183

# %% [markdown]
# # Case 01

# %%
plot_01 = sns.distplot(result_01, norm_hist=True, kde=True, rug=True, color='green')
plt.title('ELM - case 01', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_01 = np.mean(result_01)
std_01 = np.std(result_01)

print 'number of test samples = ',
print str(len(result_01))
print

print 'mean value of RMSE = ',
print str(mean_01)
print 'std value of RMSE = ',
print str(std_01)
print

print 'min RMSE = ',
print str(min(result_01))
print 'max RMSE = ',
print str(max(result_01))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.6342785
# std value of RMSE =  0.133719912286
#
# min RMSE =  0.5182
# max RMSE =  2.78

# %% [markdown]
# # Case 02

# %%
plot_02 = sns.distplot(result_02, norm_hist=True, kde=True, rug=True, color='red')
plt.title('ELM - case 02', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_02 = np.mean(result_02)
std_02 = np.std(result_02)

print 'number of test samples = ',
print str(len(result_02))
print

print 'mean value of RMSE = ',
print str(mean_02)
print 'std value of RMSE = ',
print str(std_02)
print

print 'min RMSE = ',
print str(min(result_02))
print 'max RMSE = ',
print str(max(result_02))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.73773328
# std value of RMSE =  0.505251763135
#
# min RMSE =  0.51152
# max RMSE =  9.2884

# %% [markdown]
# # Case 03

# %%
plot_03 = sns.distplot(result_03, norm_hist=True, kde=True, rug=True, color='purple')
plt.title('ELM - case 03', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_03 = np.mean(result_03)
std_03 = np.std(result_03)

print 'number of test samples = ',
print str(len(result_03))
print

print 'mean value of RMSE = ',
print str(mean_03)
print 'std value of RMSE = ',
print str(std_03)
print

print 'min RMSE = ',
print str(min(result_03))
print 'max RMSE = ',
print str(max(result_03))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.6158704
# std value of RMSE =  0.021170055315
#
# min RMSE =  0.55137
# max RMSE =  0.70164

# %% [markdown]
# # Case 04

# %%
plot_04 = sns.distplot(result_04, norm_hist=True, kde=True, rug=True, color='orange')
plt.title('ELM - case 04', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Density', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_04 = np.mean(result_04)
std_04 = np.std(result_04)

print 'number of test samples = ',
print str(len(result_04))
print

print 'mean value of RMSE = ',
print str(mean_04)
print 'std value of RMSE = ',
print str(std_04)
print

print 'min RMSE = ',
print str(min(result_04))
print 'max RMSE = ',
print str(max(result_04))
# Out:
# number of test samples =  1000
#
# mean value of RMSE =  0.57559616
# std value of RMSE =  0.0171360468794
#
# min RMSE =  0.52852
# max RMSE =  0.65414
