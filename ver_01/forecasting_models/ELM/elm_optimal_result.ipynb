# %% [markdown]
# # ELM optimal

# %%
import numpy as np
import pandas as pd
import operator

import matplotlib.pyplot as plt
# %matplotlib notebook

import seaborn as sns

# %%
result_file_00 = './elm_optimal_result00.csv'
result_file_01 = './elm_optimal_result01.csv'
result_file_02 = './elm_optimal_result02.csv'
result_file_03 = './elm_optimal_result03.csv'
result_file_04 = './elm_optimal_result04.csv'

f_00 = pd.read_csv(result_file_00)
f_01 = pd.read_csv(result_file_01)
f_02 = pd.read_csv(result_file_02)
f_03 = pd.read_csv(result_file_03)
f_04 = pd.read_csv(result_file_04)

result_00 = f_00['MAPE'].tolist()
result_01 = f_01['MAPE'].tolist()
result_02 = f_02['MAPE'].tolist()
result_03 = f_03['MAPE'].tolist()
result_04 = f_04['MAPE'].tolist()

# %% [markdown]
# # Case 00 optimal range

# %%
plot_00 = plt.plot(result_00, color='blue')
plt.title('ELM', fontsize=13)
plt.xlabel('Hidden node number', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
min_index, min_value = min(enumerate(result_00), key=operator.itemgetter(1))
print 'optimal hidden node number = ',
print min_index
# Out:
# optimal hidden node number =  4

# %% [markdown]
# # Case 01 optimal range

# %%
plot_01 = plt.plot(result_01, color='green')
plt.title('ELM', fontsize=13)
plt.xlabel('Hidden node number', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
min_index, min_value = min(enumerate(result_01), key=operator.itemgetter(1))
print 'optimal hidden node number = ',
print min_index
# Out:
# optimal hidden node number =  15

# %% [markdown]
# # Case 02 optimal range

# %%
plot_02 = plt.plot(result_02, color='red')
plt.title('ELM', fontsize=13)
plt.xlabel('Hidden node number', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
min_index, min_value = min(enumerate(result_02), key=operator.itemgetter(1))
print 'optimal hidden node number = ',
print min_index
# Out:
# optimal hidden node number =  17

# %% [markdown]
# # Case 03 optimal range

# %%
plot_03 = plt.plot(result_03, color='purple')
plt.title('ELM', fontsize=13)
plt.xlabel('Hidden node number', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
min_index, min_value = min(enumerate(result_03), key=operator.itemgetter(1))
print 'optimal hidden node number = ',
print min_index
# Out:
# optimal hidden node number =  21

# %% [markdown]
# # Case 04 optimal range

# %%
plot_04 = plt.plot(result_04, color='orange')
plt.title('ELM', fontsize=13)
plt.xlabel('Hidden node number', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
min_index, min_value = min(enumerate(result_04), key=operator.itemgetter(1))
print 'optimal hidden node number = ',
print min_index
# Out:
# optimal hidden node number =  40

# %% [markdown]
# # Total results

# %%
plot_00 = plt.plot(result_00, color='blue')
plot_00 = plt.plot(result_01, color='green')
plot_00 = plt.plot(result_02, color='red')
plot_00 = plt.plot(result_03, color='purple')
plot_00 = plt.plot(result_04, color='orange')
plt.title('ELM', fontsize=13)
plt.xlabel('Hidden node number', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">
