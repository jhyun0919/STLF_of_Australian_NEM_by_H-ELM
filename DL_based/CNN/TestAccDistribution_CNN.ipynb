# %%
import cPickle as pickle
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns

# %%
result_file_pre = 'cnn_preprocessed_result.bin'
result_file_raw = 'cnn_raw_result.bin'

f_pre = open(result_file_pre)
f_raw = open(result_file_raw)

result_pre = pickle.load(f_pre)
result_raw = pickle.load(f_raw)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-4157a33c5ec7> in <module>()
#       2 result_file_raw = 'cnn_raw_result.bin'
#       3
# ----> 4 f_pre = open(result_file_pre)
#       5 f_raw = open(result_file_raw)
#       6
#
# IOError: [Errno 2] No such file or directory: 'cnn_preprocessed_result.bin'

# %% [markdown]
# # Preprocessed

# %%
sns.distplot(result_pre, hist=True, kde=True, rug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a4b2657db743> in <module>()
# ----> 1 sns.distplot(result_pre, hist=True, kde=True, rug=True)
#
# NameError: name 'result_pre' is not defined

# %%
mean_pre = np.mean(result_pre)
std_pre = np.std(result_pre)

print 'mean value of TestAcc with preprocessed data = ',
print str(mean_pre)
print 'std value of TestAcc with preprocessed data = ',
print str(std_pre)

# %% [markdown]
# # Raw

# %%
sns.distplot(result_raw, kde=False, rug=True);
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
mean_raw = np.mean(result_raw)
std_raw = np.std(result_raw)

print 'mean value of TestAcc with raw data = ',
print str(mean_raw)
print 'std value of TestAcc with raw data = ',
print str(std_raw)
