# %%
import cPickle as pickle
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns

# %%
result_file_pre = 'cnn_preprocessed_result_00.bin'
result_file_raw = 'cnn_raw_result.bin'

f_pre = open(result_file_pre)
#f_raw = open(result_file_raw)

result_pre = pickle.load(f_pre)
#result_raw = pickle.load(f_raw)

# %% [markdown]
# # Preprocessed

# %%
plot_pre = sns.distplot(result_pre, hist=True, kde=True, rug=True)
plt.title('Convolutional Neural Network - preprocessed', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Prob', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_pre = np.mean(result_pre)
std_pre = np.std(result_pre)

print 'mean value of TestAcc with preprocessed data = ',
print str(mean_pre)
print 'std value of TestAcc with preprocessed data = ',
print str(std_pre)
print

print 'min Test RMSE = ',
print str(min(result_pre))
print 'max Test RMSE = ',
print str(max(result_pre))
# Out:
# mean value of TestAcc with preprocessed data =  2.15977
# std value of TestAcc with preprocessed data =  1.01521
#
# min Test RMSE =  0.516876
# max Test RMSE =  5.5989

# %% [markdown]
# # Raw

# %%
plot_raw = sns.distplot(result_raw, kde=False, rug=True);
plt.title('Convolutional Neural Network - raw', fontsize=13)
plt.xlabel('RMSE score', fontsize=10)
plt.ylabel('Prob', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.close()

# %%
mean_raw = np.mean(result_raw)
std_raw = np.std(result_raw)

print 'mean value of TestAcc with raw data = ',
print str(mean_raw)
print 'std value of TestAcc with raw data = ',
print str(std_raw)
print

print 'min Test RMSE = ',
print str(min(result_raw))
print 'max Test RMSE = ',
print str(max(result_raw))
